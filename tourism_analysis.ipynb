# %%
from tabula import read_pdf

# %%
df = read_pdf("19_removed.pdf", multiple_tables=False)

# %%
df
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 FLIGHT MOVEMENT       PASSENGER MOVEMENT  \
# 0        S.N.   AIRLINES        NaN             NaN                      NaN
# 1         NaN        NaN        DEP       ARR TOTAL             OUT IN TOTAL
# 2           1        ABY        880        880 1760     106394 126024 232418
# 3           2        AIC        939        939 1878     113687 123754 237441
# 4           3        BBC        354         354 708        39658 33154 72812
# 5           4        BHA         70          72 142           2294 2102 4396
# 6           5        BTN        290         290 580          6677 3951 10628
# 7           6        CCA        513        513 1026        48281 47006 95287
# 8           7        CES        556        556 1112       52089 53327 105416
# 9           8        CSC        204         204 408        13546 14012 27558
# 10          9        CSN        729        729 1458       84802 73841 158643
# 11         10        DRK        411         411 822        23280 27455 50735
# 12         11        ETD        579        579 1158       64453 66784 131237
# 13         12        FDB       1175       1175 2350     171660 165804 337464
# 14         13        HDA        233         233 466       65479 54130 119609
# 15         14        HIM        887        883 1770     120926 103227 224153
# 16         15        IGO        365         365 730       57259 58913 116172
# 17         16        JAI       1569       1569 3138     226454 224495 450949
# 18         17        KAL        191         191 382        37252 35525 72777
# 19         18        MAS        361         361 722        49391 48331 97722
# 20         19        MXD        688        688 1376      75497 102308 177805
# 21         20        NAC       1779       1776 3555     244618 247361 491979
# 22         21        OMA        770        770 1540       78895 88234 167129
# 23         22        QTR       1455       1455 2910     193534 205802 399336
# 24         23        RGE         88          88 176          7549 7442 14991
# 25         24        SLK        294         294 588        39215 35206 74421
# 26         25        TBA        221         221 442        19584 17759 37343
# 27         26        THA        365         365 730       91761 79234 170995
# 28         27        THY        254         254 508       62183 54387 116570
# 29         28        UBG         42           42 84           1865 2492 4357
# 30         29        WAN        145         145 290        20196 10275 30471
# 31         29        XAX        149         149 298        29669 43302 72971
# 32         30     OTHERS        408         410 818        25791 23790 49581
# 33        NaN      TOTAL      16964     16961 33925  2173939 2179427 4353366
#
#    Unnamed: 5
# 0     TRANSIT
# 1         NaN
# 2           0
# 3          18
# 4          12
# 5           0
# 6           1
# 7          74
# 8           0
# 9           1
# 10          3
# 11         35
# 12         23
# 13         88
# 14         39
# 15         94
# 16          3
# 17          4
# 18          7
# 19         40
# 20          8
# 21        429
# 22         10
# 23         13
# 24          2
# 25          0
# 26          1
# 27         34
# 28         11
# 29          0
# 30          0
# 31          1
# 32          0
# 33        951

# %%
from tabula import convert_into

convert_into("19_removed.pdf", "pashinath.csv", output_format="csv")

# %%
import pandas as pd 

df = pd.read_csv('data.csv')
df = df.drop(['Total'], axis=1)
df.head()
# Out:
#   Nationality  Year  Jan.  Feb.  Mar.  Apr.   May Jun.   Jul.  Aug.    Sep.  \
# 0   Australia  2016  1660  1648   354  2416  1233  1037   983  1038  3253.0
# 1   Australia  2017  2735  2386  3141  3707  1692  1532   814  1007  4141.0
# 2   Australia  2018  2689  2537  3605  3805  1903  1619  1718  1406  3746.0
# 13      France  2017   942  1566   2697  3451  1203   852 1025  1025  1073
#
#       Sep.  Oct.     Nov.   Dec.
# 1   4141.0  4297   4582.0   3337
# 4   3683.0  2418   2784.0   4212
# 7   1245.0  2333   1714.0   1135
# 10  8351.0  9735  10312.0  11010
# 13  1991.0  6332   3695.0   1313

# %%
df3 = df.iloc[2::3]
df3.head()
# Out:
#    Nationality  Year   Jan.   Feb.   Mar.   Apr.   May       Jun.    Jul.  \
# 2    Australia  2018   2689   2537   3605   3805  1903        1619   1718
# 5   Bangladesh  2018   2743   3236   2946   2028  1191        1850   1407
# 8       Canada  2018    955   1511   2086   1827  1174         805    921
# 11       China  2018  12027  15394  13558  12554  9148  8696 13122  13122
# 14      France  2018   1160   1863   3260   4453  1525    736 1620   1620
#
#      Aug.     Sep.   Oct.     Nov.   Dec.
# 2    1406   3746.0   5826   5140.0   4435
# 5    2311   1854.0   1843   2125.0   2821
# 8     775   1222.0   2700   2134.0   1207
# 11  12048  12934.0  13538  14862.0  15752
# 14   1349   2362.0   7552   4340.0   1590

# %%
def draw_country_vs_number(dataframe):
    dataframe = dataframe.drop(['Year'], axis=1)
    s = dataframe.plot.line()

# %%
draw_country_vs_number(df3)

# %%
gender_df = pd.read_csv('gender.csv', header=0)
gender_df.fillna(0, inplace=True)
gender_df.head()
# Out:
#    S.No.                   Peak  Female  Male  Total (Permit issued)  \
# 0      1         Aichyn (6055m)     3.0    13                     16
# 1      2      Amadablam(6814m.)    43.0   300                    343
# 2      3  Anidesh Chuli (6960m)     0.0     6                      6
# 3      4      Annapurna(8091m.)     0.0     9                      9
# 4      5            Api (7132m)     2.0     8                     10
#
#    Female.1  Male.1  Total (Summitted)
# 0       2.0     8.0               10.0
# 1      39.0   263.0              302.0
# 2       0.0     0.0                0.0
# 3       0.0     5.0                5.0
# 4       0.0     0.0                0.0

# %%
def proportion_calculator(permits, summits):
    return permits / summits * 100

# %%
import re 

def get_height_from_name(peak_name):
    pat = r'.*?\((.*)m.*'
    match = re.search(pat, peak_name)
#     print(f"match: {match.group(1)}")
    return (int)(match.group(1))   

def filter_on_height(df, height):
    df = df[df.apply(lambda x: get_height_from_name(x['Peak']) > height, axis=1)]
    return df

# %%
def calculate_average(list_of_permits, list_of_summits):
    print(list_of_permits)
    print(list_of_summits)
    list_of_proportions = []
    for (i,j) in zip(list_of_permits, list_of_summits):
        try:
            list_of_proportions.append(j/i)
        except ZeroDivisionError:
            list_of_proportions.append(0)
    return sum(list_of_proportions)/len(list_of_proportions) * 100

# %%
def get_proportion_based_on_height(df, height):
    new_df = filter_on_height(gender_df, height)
    prop = calculate_average(new_df['Female'].tolist(), new_df['Female.1'].tolist())
    print(f"Proportion of climbers who successfully summitted: {prop}")

# %%
get_proportion_based_on_height(gender_df, 8500)
# Out:
# [64.0, 8.0, 24.0]
# [52.0, 5.0, 9.0]
# Proportion of climbers who successfully summitted: 60.416666666666664
