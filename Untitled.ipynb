# %%
from tabula import read_pdf

# %%
df = read_pdf("19_removed.pdf", multiple_tables=False)

# %%
df
# Out:
#                            Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                    Nationality Year        NaN        NaN        NaN
# 1                                 NaN       Jan.        NaN       Feb.
# 2                                2016      2,205        NaN      2,984
# 3                                  UK        NaN        NaN        NaN
# 4                                2017       3395        NaN       4363
# 5                                 NaN        NaN        NaN        NaN
# 6                                2018       3250        NaN       4884
# 7                                2016      3,627        NaN      4,144
# 8                            USA 2017       5626        NaN       5847
# 9                                2018       5499        NaN       6807
# 10                               2016      4,453        NaN      5,911
# 11                        Others 2017       7495      10646        NaN
# ...

# %%
from tabula import convert_into

convert_into("19_removed.pdf", "data.csv", output_format="csv")
